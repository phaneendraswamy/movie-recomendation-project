# %%
import pandas as pd

# %%
movies=pd.read_csv(r"C:\Users\Swamy\Downloads\top10K-TMDB-movies.csv\top10K-TMDB-movies.csv")

# %%
movies
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                  genre original_language  \
# 0                                          Drama,Crime                en
# 1                                 Comedy,Drama,Romance                hi
# ...

# %%
movies.isnull().sum()
# Out:
# id                    0
# title                 0
# genre                 3
# original_language     0
# overview             13
# popularity            0
# release_date          0
# vote_average          0
# vote_count            0
# dtype: int64

# %%
movies.columns
# Out:
# Index(['id', 'title', 'genre', 'original_language', 'overview', 'popularity',
#        'release_date', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
movies=movies[['id', 'title', 'overview', 'genre']]

# %%
movies
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
movies['tags'] = movies['overview']+movies['genre']
# Out:
# C:\Users\Swamy\AppData\Local\Temp\ipykernel_25088\3329298957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['tags'] = movies['overview']+movies['genre']

# %%
movies
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
movies
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
new_data  = movies.drop(columns=['overview', 'genre'])

# %%
new_data
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(max_features=10000, stop_words='english')

# %%
cv
# Out:
# CountVectorizer(max_features=10000, stop_words='english')

# %%
vector=cv.fit_transform(new_data['tags'].values.astype('U')).toarray()

# %%
vector.shape
# Out:
# (10000, 10000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.05634362, 0.12888482, ..., 0.07559289, 0.11065667,
#         0.06388766],
#        [0.05634362, 1.        , 0.07624929, ..., 0.        , 0.03636965,
#         0.        ],
#        [0.12888482, 0.07624929, 1.        , ..., 0.02273314, 0.06655583,
#         0.08645856],
#        ...,
#        [0.07559289, 0.        , 0.02273314, ..., 1.        , 0.03253   ,
#         0.02817181],
#        [0.11065667, 0.03636965, 0.06655583, ..., 0.03253   , 1.        ,
#         0.0412393 ],
#        [0.06388766, 0.        , 0.08645856, ..., 0.02817181, 0.0412393 ,
#         1.        ]])

# %%
new_data[new_data['title']=="The Godfather"].index[0]
# Out:
# 2

# %%
distance = sorted(list(enumerate(similarity[2])), reverse=True, key=lambda vector:vector[1])
for i in distance[0:5]:
    print(new_data.iloc[i[0]].title)
# Out:
# The Godfather
# The Godfather: Part II
# Blood Ties
# Joker
# Bomb City

# %%
import streamlit as st

# %%
st.write(movies.columns)
# Out:
# 2024-12-15 13:05:54.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-15 13:05:54.895
# ...
#   command:
#
#     streamlit run c:\Users\Swamy\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-12-15 13:05:54.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
print(movies.columns)
# Out:
# Index(['id', 'title', 'overview', 'genre', 'tags'], dtype='object')

# %% [markdown]
# function

# %%
import requests

# Function to fetch the poster using the OMDb API and the movie id
def fetch_poster(movie_id):
    # Use OMDb API to get movie details based on the title or ID
    url = f"http://www.omdbapi.com/?i={movie_id}&apikey=584ab2ff"
    response = requests.get(url)
    data = response.json()

    if data['Response'] == 'True':
        return data['Poster']
    else:
        return None  # Return None if no poster is found

# Function to recommend similar movies
def recommend(movie):
    # Check if the movie exists in the DataFrame
    if movie not in movies['title'].values:
        return [], []  # Return empty lists if the movie is not found

    index = movies[movies['title'] == movie].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector: vector[1])
    recommend_movie = []
    recommend_poster = []

    for i in distance[1:6]:  # Get top 5 similar movies
        movie_id = movies.iloc[i[0]]['id']  # Use the 'id' column to fetch the poster
        poster = fetch_poster(movie_id)  # Fetch the poster using the movie id
        
        # Add movie title and poster to the recommendation list
        recommend_movie.append(movies.iloc[i[0]].title)
        recommend_poster.append(poster)

    return recommend_movie, recommend_poster

# %% [markdown]
# other

# %%
import requests
import pandas as pd

# Function to fetch the poster using the OMDb API and the movie title
def fetch_poster(movie_title):
    # Use OMDb API to get movie details based on the title
    url = f"http://www.omdbapi.com/?t={movie_title}&apikey=584ab2ff"
    response = requests.get(url)
    data = response.json()

    if data['Response'] == 'True':
        return data['Poster']  # Return the poster URL if found
    else:
        return None  # Return None if no poster is found

# Function to recommend similar movies
def recommend(movie, movies, similarity):
    if movie not in movies['title'].values:
        return [], []  # Return empty lists if the movie is not found

    index = movies[movies['title'] == movie].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector: vector[1])
    recommend_movie = []
    recommend_poster = []

    for i in distance[1:6]:  # Get top 5 similar movies
        movie_title = movies.iloc[i[0]]['title']  # Use the movie title to fetch the poster
        poster = fetch_poster(movie_title)  # Fetch the poster using movie title
        
        # Add movie title and poster to the recommendation list
        recommend_movie.append(movie_title)
        recommend_poster.append(poster)

    return recommend_movie, recommend_poster

# Example dataset with 'id', 'title', 'overview', 'genre' columns
movies =new_data

# Example similarity matrix (this should be replaced with your actual similarity matrix)
similarity =similarity

# Example usage of the recommend function
recommended_movies, posters = recommend('The Godfather', movies, similarity)

# Output the recommended movies and posters
for i in range(len(recommended_movies)):
    print(f"Recommended Movie: {recommended_movies[i]}")
    if posters[i] is None:
        print("No poster available.")
    else:
        print(f"Poster URL: {posters[i]}")
# Out:
# Recommended Movie: The Godfather: Part II
# Poster URL: https://m.media-amazon.com/images/M/MV5BNzc1OWY5MjktZDllMi00ZDEzLWEwMGItYjk1YmRhYjBjNTVlXkEyXkFqcGc@._V1_SX300.jpg
# Recommended Movie: Blood Ties
# Poster URL: https://m.media-amazon.com/images/M/MV5BMTM5NDc5NTc5MF5BMl5BanBnXkFtZTgwNDA2MjMwMTE@._V1_SX300.jpg
# Recommended Movie: Joker
# Poster URL: https://m.media-amazon.com/images/M/MV5BNzY3OWQ5NDktNWQ2OC00ZjdlLThkMmItMDhhNDk3NTFiZGU4XkEyXkFqcGc@._V1_SX300.jpg
# Recommended Movie: Bomb City
# Poster URL: https://m.media-amazon.com/images/M/MV5BNTcxYWE5NDktYmNjOS00NzE2LThiMTgtODUwYzc5MDMzODQ3XkEyXkFqcGc@._V1_SX300.jpg
# Recommended Movie: Gotti
# Poster URL: https://m.media-amazon.com/images/M/MV5BMjAyODI1NDMxOV5BMl5BanBnXkFtZTgwNDg0Njg0NTM@._V1_SX300.jpg

# %%
import requests
import pandas as pd

# Function to fetch the poster using the OMDb API and the movie title
def fetch_poster(movie_title):
    # Use OMDb API to get movie details based on the title
    url = f"http://www.omdbapi.com/?t={movie_title}&apikey=584ab2ff"
    response = requests.get(url)
    data = response.json()

    if data['Response'] == 'True':
        return data['Poster']  # Return the poster URL if found
    else:
        return None  # Return None if no poster is found

# Example dataset with 'id', 'title', 'overview', 'genre' columns
movies = pd.DataFrame({
    'id': [1],
    'title': ['The Godfather'],
    'overview': ['Crime drama'],
    'genre': ['Crime']
})

# Fetch the poster for "The Godfather"
movie_title = 'The Godfather'
poster = fetch_poster(movie_title)

# Output the poster URL or a message if no poster is available
print(f"Movie: {movie_title}")
if poster is None:
    print("No poster available.")
else:
    print(f"Poster URL: {poster}")
# Out:
# Movie: The Godfather
# Poster URL: https://m.media-amazon.com/images/M/MV5BYTJkNGQyZDgtZDQ0NC00MDM0LWEzZWQtYzUzZDEwMDljZWNjXkEyXkFqcGc@._V1_SX300.jpg

# %%
print(movies['title'].unique())
# Out:
# ['The Godfather']

# %%
import pickle

# %%
pickle.dump(new_data, open('movies_list.pkl', 'wb'))

# %%
pickle.dump(similarity, open('similarity.pkl', 'wb'))

# %%
pickle.load(open('movies_list.pkl', 'rb'))
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
import requests

# Test API for "The Godfather"
movie_title = "The Godfather"
api_key = "584ab2ff"
url = f"http://www.omdbapi.com/?t={movie_title.replace(' ', '+')}&apikey={api_key}"

response = requests.get(url)
data = response.json()

print(data)  # This will show the full API response for the movie
# Out:
# {'Title': 'The Godfather', 'Year': '1972', 'Rated': 'R', 'Released': '24 Mar 1972', 'Runtime': '175 min', 'Genre': 'Crime, Drama', 'Director': 'Francis Ford Coppola', 'Writer': 'Mario Puzo, Francis Ford Coppola', 'Actors': 'Marlon Brando, Al Pacino, James Caan', 'Plot': 'The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.', 'Language': 'English, Italian, Latin', 'Country': 'United States', 'Awards': 'Won 3 Oscars. 31 wins & 31 nominations total', 'Poster': 'https://m.media-amazon.com/images/M/MV5BYTJkNGQyZDgtZDQ0NC00MDM0LWEzZWQtYzUzZDEwMDljZWNjXkEyXkFqcGc@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '9.2/10'}, {'Source': 'Rotten Tomatoes', 'Value': '97%'}, {'Source': 'Metacritic', 'Value': '100/100'}], 'Metascore': '100', 'imdbRating': '9.2', 'imdbVotes': '2,068,172', 'imdbID': 'tt0068646', 'Type': 'movie', 'DVD': 'N/A', 'BoxOffice': '$136,381,073', 'Production': 'N/A', 'Website': 'N/A', 'R
# ...

# %%
# Function to fetch the poster using the OMDb API and the movie id
def fetch_poster(movie_id):
    # OMDb API URL with movie ID
    url = f"http://www.omdbapi.com/?i={movie_id}&apikey=584ab2ff"
    
    # Send request to the OMDb API
    response = requests.get(url)
    
    # Parse the response as JSON
    data = response.json()

    # Print the response to check if the data contains a valid poster
    print(f"Fetched data for movie_id {movie_id}: {data}")  # Debug line

    # Check if the response is valid and contains a poster URL
    if data.get('Response') == 'True' and data.get('Poster') != 'N/A':
        return data.get('Poster')  # Return poster URL if it's valid
    else:
        return None  # Return None if no valid poster is found or API response is invalid

# %%
# Function to fetch the poster using the OMDb API and the movie id
def fetch_poster(movie_id):
    url = f"http://www.omdbapi.com/?i={movie_id}&apikey=584ab2ff"
    response = requests.get(url)
    data = response.json()

    print(f"API response for {movie_id}: {data}")  # Debug line

    if data.get('Response') == 'True':
        poster = data.get('Poster', 'N/A')
        if poster != 'N/A':
            return poster  # Return valid poster
        else:
            print(f"No poster found for {movie_id}")  # Debug line if no poster
            return None  # No poster found
    else:
        print(f"Failed to fetch data for {movie_id}: {data.get('Error')}")  # Debug line if API fails
        return None

# %%
def recommend(movie, movies, similarity):
    if movie not in movies['title'].values:
        return [], []  # Return empty lists if the movie is not found

    index = movies[movies['title'] == movie].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector: vector[1])
    recommend_movie = []
    recommend_poster = []

    for i in distance[1:6]:  # Get top 5 similar movies
        movie_id = movies.iloc[i[0]]['id']  # Ensure this is the correct ID
        poster = fetch_poster(movie_id)  # Fetch the poster using the correct ID
        
        recommend_movie.append(movies.iloc[i[0]].title)
        recommend_poster.append(poster)

    return recommend_movie, recommend_poster

# %%
def recommend(movie, movies, similarity):
    if movie not in movies['title'].values:
        return [], []  # Return empty lists if the movie is not found

    index = movies[movies['title'] == movie].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector: vector[1])
    
    recommend_movie = []
    recommend_poster = []

    for i in distance[1:6]:  # Get top 5 similar movies
        movie_index = i[0]  # The index of the movie in the DataFrame
        movie_id = movies.iloc[movie_index]['id']  # Use the correct index to get the movie ID
        poster = fetch_poster(movie_id)  # Fetch the poster using the movie ID
        
        # Append movie title and poster to the recommendation list
        recommend_movie.append(movies.iloc[movie_index].title)
        recommend_poster.append(poster)

    return recommend_movie, recommend_poster

# %%
import requests

url = "https://ott-details.p.rapidapi.com/advancedsearch"

querystring = {"start_year":"1970","end_year":"2020","min_imdb":"6","max_imdb":"7.8","genre":"action","language":"english","type":"movie","sort":"latest","page":"1"}

headers = {
	"x-rapidapi-key": "8ebcdd5cf6mshb9ecedd9accfacap115f4djsnc47b3df114b9",
	"x-rapidapi-host": "ott-details.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'page': 1, 'results': [{'imageurl': ['https://m.media-amazon.com/images/M/MV5BNzY3YTUwYTQtNjkwNy00OTAyLWE0OWEtYmE3MGIyOWZkODY1XkEyXkFqcGdeQXVyMjkyNzYwMTc@._V1_UX182_CR0,0,182,268_AL_.jpg'], 'genre': ['Action', 'Adventure', 'Animation'], 'imdbid': 'tt9580138', 'title': "Mortal Kombat Legends: Scorpion's Revenge", 'imdbrating': 7.4, 'released': 2020, 'synopsis': 'Hanzo Hasashi loses his clan, family, and his life during an attack by a rival ninja clan. He is given the chance to compete in an interdimensional tournament to save his loved ones.', 'type': 'movie'}, {'imageurl': ['https://m.media-amazon.com/images/M/MV5BMmUyYTU5MjItMGNhOC00ZGFhLTkwYjctMjBmNTlkOTIzYmM1XkEyXkFqcGdeQXVyOTUyOTM3MDc@._V1_UY268_CR110,0,182,268_AL_.jpg'], 'genre': ['Action', 'Adventure', 'Drama'], 'imdbid': 'tt9286908', 'title': 'High Ground', 'imdbrating': 6.5, 'released': 2020, 'synopsis': 'In a bid to save the last of his family, Gutjuk, a young Aboriginal man, teams up with ex-soldier Travis to track down Ba
# ...
